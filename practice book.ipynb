# %%
thistuple=(1,2,3,4,5,6,7,8)
print(thistuple[:4:7])
# Out:
# (1,)

# %%
def add(x):
  x=x+10
n=10
add(n)
print(n)
# Out:
# 10

# %%
a=[[1,2],[3,4]]
b=a[:]
b[0].append(9)
print(a)
# Out:
# [[1, 2, 9], [3, 4]]

# %%
a=[1,2,3]
b=a[:]
b.append(5)
print(a)
print(b)
# Out:
# [1, 2, 3]
# [1, 2, 3, 5]

# %%
crop_yield=int(input("enter the crop yirld"))
if crop_yield>=50:
  print("high")
elif crop_yield>=30:
  print("med")
else:
  print("low")
# Out:
# enter the crop yirld35
# med

# %%
t=[1,2,3,4,5,6,7]
print(t[-5:1:-2])
# Out:
# [3]
