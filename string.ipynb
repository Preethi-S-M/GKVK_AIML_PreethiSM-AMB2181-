# %%
#creating strings
crop="Rice"
soiltype="blacksoil"
print(crop)
print(soiltype)
# Out:
# Rice
# blacksoil

# %%
# length of strings return the number of charcater
print(len(crop))
print(len(soiltype))
# Out:
# 4
# 9

# %%
# indexing and slicing
crop="Groundnut"
print(crop[0])
print(crop[-1])
print(crop[:5])
print(crop[5:])
# Out:
# G
# t
# Groun
# dnut

# %%
# case sensitive operations
print("rice".upper())
print("WHEAT".lower())
print("black gram".title())
print("cotton candy".capitalize())
# Out:
# RICE
# wheat
# Black Gram
# Cotton candy

# %%
# trimming and cleaning strings
print("     rice    ".strip())
print("****wheat".strip("*"))
print("cotton######".rstrip("#"))
# Out:
# rice
# wheat
# cotton

# %%
# searching and counting substring
text="Organic Rice and Rice cultivation"
print(text.find("Rice"))
print(text.count("Rice"))
print("Rice" in text)
# Out:
# 8
# 2
# True

# %%
# extract and clean
crops=["CRP_RICE_2025","CRP_WHEAT_2026","FRT_MANGO_2023","CRP_MAIZE_2025"]
cleancode=[]
for crop in crops:
  if crop.startswith("CRP"):
    cleancode.append(crop[4:])
print(cleancode)
# Out:
# ['RICE_2025', 'WHEAT_2026', 'MAIZE_2025']

# %%
for crop in crops:
  if crop.startswith("CRP"):
    print(crop[4:])
# Out:
# RICE_2025
# WHEAT_2026
# MAIZE_2025

# %%
for crop in crops:
  if crop.startswith("CRP"):
    code,cropss,year=crop.split("_")
    print(cropss,year)
# Out:
# RICE 2025
# WHEAT 2026
# MAIZE 2025

# %%
rawrecord="        Rice,black soil,1200        "
cleanedrecord=rawrecord.strip()
crop,soil,yield_kg=cleanedrecord.split(",")
crop=crop.title()

print(f"crop:{crop} \nsoil:{soil} \nyield_kg:{yield_kg}")
# Out:
# crop:Rice
# soil:black soil
# yield_kg:1200
