# %%
thistuple=("apple","banana","cherry")
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
fruits=("apple","banana","cherry")
y=list(fruits)
y[2]="kiwi"
x=tuple(y)
print(x)
print(y)
# Out:
# ('apple', 'banana', 'kiwi')
# ['apple', 'banana', 'kiwi']
