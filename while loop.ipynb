# %%
# while loop
count=1
while count<=5:
  print(count)
  count+=1
print("end of the program")
# Out:
# 1
# 2
# 3
# 4
# 5
# end of the program

# %%
#example
water_level=20
while water_level<50:
  print("irrigation on - water level",water_level)
  water_level+=5
print("Sufficient water. Irrigation off")
# Out:
# irrigation on - water level 20
# irrigation on - water level 25
# irrigation on - water level 30
# irrigation on - water level 35
# irrigation on - water level 40
# irrigation on - water level 45
# Sufficient water. Irrigation off

# %%
# infinite loop
#break
count=1
while True:
  print(count)
  if count==5:
    break
  count+=1

# continue
count=0
while count<5:
  count+=1
  if count==3:
    continue
  print(count)
# Out:
# 1
# 2
# 3
# 4
# 5
# 1
# 2
# 4
# 5

# %%
#while else
count=1
while count<=3:
  print(count)
  count+=1
print("loop completed")
# Out:
# 1
# 2
# 3
# loop completed

# %%
irrigation=int(input("enter irrigation level"))
soil_moisture=int(input("enter soil moisture level"))
while count<=3:
  print(count)
  count+=1
print("loop completed")
# Out:
# enter irrigation level10
# enter soil moisture level10
# loop completed
